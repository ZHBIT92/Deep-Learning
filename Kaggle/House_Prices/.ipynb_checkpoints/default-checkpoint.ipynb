# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')
print ("Train data shape:", train.shape)
print ("Test data shape:", test.shape)
# Out:
# Train data shape: (1460, 81)
# Test data shape: (1459, 80)

# %% [markdown]
# 因为测试数据不包括最终销售价格信息，所以 *test* 比 *train* 少一列

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# * SalePrice - 以美元为单位的物业销售价格 这是你试图预测的目标变量
# * MSSubClass - 建筑类
# * MSZoning - 一般的分区划分
# * LotFrontage - 街道的线性脚与物业相连
# * LotArea - 以平方英尺为单位的土地面积
# * Street - 进入道路的类型
# * Alley - 胡同入口的类型
# * LotShape - 属性的一般形状
# * LandContour - 酒店的平坦度
# * Utilities - 可用的实用程序类型
# * LotConfig - 批量配置

# %%
import matplotlib.pyplot as plt
plt.style.use(style='ggplot')
plt.rcParams['figure.figsize'] = (10, 6)

# %%
train.SalePrice.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# Series.describe()函数获取销售价格的详细信息

# %%
# 用plt.hist()绘制直方图SalePrice来检测偏移量
print ("Skew is:", train.SalePrice.skew())
plt.hist(train.SalePrice, color='blue')
plt.show()
# Out:
# Skew is: 1.88287575977

# %% [markdown]
# np.log()会改变目标变量，使用np.log()转换train.SalePric和计算偏斜度

# %%
target = np.log(train.SalePrice)
print ("Skew is:", target.skew())
plt.hist(target, color='blue')
plt.show()
# Out:
# Skew is: 0.121335062205

# %% [markdown]
# 可以看到数据更接近正态分布，说明已经改善了数据的偏移度

# %% [markdown]
# ## 接下来我们检查数字特征
# .select_dtypes()方法将返回匹配指定数据类型的列的子集

# %%
numeric_features = train.select_dtypes(include=[np.number])
numeric_features.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# LotFrontage      float64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# MasVnrArea       float64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageYrBlt      float64
# GarageCars         int64
# GarageArea         int64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# ...

# %% [markdown]
# DataFrame.corr()方法显示列之间的相关性（或关系）

# %%
corr = numeric_features.corr()

print (corr['SalePrice'].sort_values(ascending=False)[:5], '\n')
print (corr['SalePrice'].sort_values(ascending=False)[-5:],'\n')
# Out:
# SalePrice      1.000000
# OverallQual    0.790982
# GrLivArea      0.708624
# GarageCars     0.640409
# GarageArea     0.623431
# Name: SalePrice, dtype: float64
#
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# EnclosedPorch   -0.128578
# KitchenAbvGr    -0.135907
# Name: SalePrice, dtype: float64

# %% [markdown]
# 前五个特征与最正相关SalePrice，而后五个特征与负相关性最大。

# %%
train.OverallQual.unique()
# Out:
# array([ 7,  6,  8,  5,  9,  4, 10,  3,  1,  2], dtype=int64)

# %% [markdown]
# .unique()方法来去除重复的元素以获得唯一的值，发现OverallQual数据是整数值在区间1到10以下

# %% [markdown]
# ### 对OverallQual和SalePrice之间的关系进行探究
# pivot_table()建立一个数据透视表，np.median()返回数组元素的中位数

# %%
quality_pivot = train.pivot_table(index='OverallQual',
                                  values='SalePrice', aggfunc=np.median)
quality_pivot
# Out:
#              SalePrice
# OverallQual
# 1                50150
# 2                60000
# 3                86250
# 4               108000
# 5               133000
# 6               160000
# 7               200141
# 8               269750
# 9               345000
# 10              432390

# %% [markdown]
# 使用Series.plot()方法创建一个条形图

# %%
quality_pivot.plot(kind='bar', color='blue')
plt.xlabel('Overall Quality')
plt.ylabel('Median Sale Price')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# 可以发现随着整体质量的提高，中位销售价格严重上涨

# %% [markdown]
# ### 对GrLivArea(地面生活区)、GarageArea(车库面积)和SalePrice之间的关系进行探究

# %%
plt.scatter(x=train['GrLivArea'], y=target)
plt.ylabel('Sale Price')
plt.xlabel('Above grade (ground) living area square feet')
plt.show()

# %% [markdown]
# 我们看到居住面积的增加与价格上涨相对应，但接下来我们看下GarageArea与SalePrice之间的关系

# %%
plt.scatter(x=train['GarageArea'], y=target)
plt.ylabel('Sale Price')
plt.xlabel('Garage Area')
plt.show()

# %% [markdown]
# 发现许多家庭的Garage Area值为0，说明他们没有车库。
#
# 接下来我们将创建一个删除了一些异常值的新数据框

# %%
train = train[train['GarageArea'] < 1200]
plt.scatter(x=train['GarageArea'], y=np.log(train.SalePrice))
plt.xlim(-200,1600) # This forces the same scale as before
plt.ylabel('Sale Price')
plt.xlabel('Garage Area')
plt.show()

# %% [markdown]
# ## 处理空值
# * isnull()函数判断是否为空
# * sum()函数计数

# %%
nulls = pd.DataFrame(train.isnull().sum().sort_values(ascending=False)[:25])
nulls.columns = ['Null Count']
nulls.index.name = 'Feature'
nulls
# Out:
#               Null Count
# Feature
# PoolQC              1449
# MiscFeature         1402
# Alley               1364
# Fence               1174
# FireplaceQu          689
# LotFrontage          258
# GarageCond            81
# GarageType            81
# GarageYrBlt           81
# GarageFinish          81
# GarageQual            81
# BsmtExposure          38
# BsmtFinType2          38
# BsmtFinType1          37
# BsmtCond              37
# BsmtQual              37
# MasVnrArea             8
# MasVnrType             8
# Electrical             1
# Utilities              0
# YearRemodAdd           0
# MSSubClass             0
# Foundation             0
# ExterCond              0
# ExterQual              0

# %%
print ("Unique values are:", train.MiscFeature.unique())
# Out:
# Unique values are: [nan 'Shed' 'Gar2' 'Othr' 'TenC']

# %% [markdown]
# * Elev ：电梯
# * Gar2：第二车库（如果在车库部分没有描述）
# * Othr ：其他
# * Shed：棚子（超过100平方英尺）
# * TenC：网球场

# %% [markdown]
# ## 修改非数字特征

# %%
categoricals = train.select_dtypes(exclude=[np.number])
categoricals.describe()
# Out:
# Feature MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count       1455   1455    91     1455        1455      1455      1455
# unique         5      2     2        4           4         2         5
# top           RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq        1147   1450    50      921        1309      1454      1048
#
# Feature LandSlope Neighborhood Condition1      ...      GarageType  \
# count        1455         1455       1455      ...            1374
# unique          3           25          9      ...               6
# top           Gtl        NAmes       Norm      ...          Attchd
# freq         1378          225       1257      ...             867
#
# Feature GarageFinish GarageQual GarageCond PavedDrive PoolQC  Fence  \
# count           1374       1374       1374       1455      6    281
# unique             3          5          5          3      3      4
# ...

# %% [markdown]
# 该count列表示非空观测unique值的计数，同时计数唯一值的数量。top是最常见的值，最高值的频率显示为freq。

# %% [markdown]
# 对Street数据探究

# %%
print ("Original: \n") 
print (train.Street.value_counts(), "\n")
# Out:
# Original:
#
# Pave    1450
# Grvl       5
# Name: Street, dtype: int64

# %% [markdown]
# 设计一个Street特征

# %%
train['enc_street'] = pd.get_dummies(train.Street, drop_first=True)
test['enc_street'] = pd.get_dummies(train.Street, drop_first=True)
print ('Encoded: \n') 
print (train.enc_street.value_counts())
# Out:
# Encoded:
#
# 1    1450
# 0       5
# Name: enc_street, dtype: int64

# %% [markdown]
# SaleCondition - 出售条件  表格显示其中间销售价格

# %%
condition_pivot = train.pivot_table(index='SaleCondition',
                                    values='SalePrice', aggfunc=np.median)
condition_pivot.plot(kind='bar', color='blue')
plt.xlabel('Sale Condition')
plt.ylabel('Median Sale Price')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# Partial中间销售价格明显高于其他中间销售价格。我们会将其编码为一项新功能。
#
# 我们选择所有SaleCondition等于Patrial并分配值的房屋1，否则（other）分配0

# %%
def encode(x): return 1 if x == 'Partial' else 0
train['enc_condition'] = train.SaleCondition.apply(encode)
test['enc_condition'] = test.SaleCondition.apply(encode)

# %%
condition_pivot = train.pivot_table(index='enc_condition', values='SalePrice', aggfunc=np.median)
condition_pivot.plot(kind='bar', color='blue')
plt.xlabel('Encoded Sale Condition')
plt.ylabel('Median Sale Price')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# DataFrame.interpolate()方法：用平均值填充缺失的值，然后将结果分配给data

# %%
data = train.select_dtypes(include=[np.number]).interpolate().dropna()

# %%
#检查所有的列是否有0个空值。
sum(data.isnull().sum() != 0)
# Out:
# 0

# %% [markdown]
# ## 建立一个线性模型
# 我们将分离功能和目标变量进行建模。
# * 使用np.log()上面解释的方法来转换模型的y变量。
# * data.drop([features], axis=1)方法来排除列

# %%
y = np.log(train.SalePrice)
X = data.drop(['SalePrice', 'Id'], axis=1)

# %% [markdown]
# ## 使用scikit-learn的train_test_split()功能来创建一个训练集和一个保留集
# train_test_split() 返回四个对象：
#
# * `X_train` 是我们用于培训的功能的子集。
# * `X_test`  是将成为我们的“保留”集合的子集 - 我们将用来测试模型。
# * `y_train` 是SalePrice相应的目标变量`X_train`。
# * `y_test` 是SalePrice相应的目标变量`X_test`。
#
# 参数值
# * `X`表示预测变量数据集，并且`y`是目标变量。
# * `random_state=42`，这提供了可重复的结果，
# * `train_test_split`将随机分配数据。该`test_size`参数告诉函数在test分区中应该有多少数据。在这个例子中，大约33％的数据专用于保留集。

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
                                    X, y, random_state=42, test_size=.33)

# %% [markdown]
# 实例化一个线性回归模型

# %%
from sklearn import linear_model
lr = linear_model.LinearRegression()

# %%
model = lr.fit(X_train, y_train)

# %%
print ("R^2 is: \n", model.score(X_test, y_test))
# Out:
# R^2 is:
#  0.888247770926

# %% [markdown]
# model.predict()方法将返回给定一组预测变量的预测列表。model.predict()在拟合模型后使用。

# %%
predictions = model.predict(X_test)

# %% [markdown]
# `mean_squared_error`函数需要两个数组并计算`rmse`

# %%
from sklearn.metrics import mean_squared_error
print ('RMSE is: \n', mean_squared_error(y_test, predictions))
# Out:
# RMSE is:
#  0.0178417945196

# %% [markdown]
# * `RMSE`：测量我们的预测值和实际值之间的距离

# %%
actual_values = y_test
plt.scatter(predictions, actual_values, alpha=.75,
            color='b') #alpha helps to show overlapping data
plt.xlabel('Predicted Price')
plt.ylabel('Actual Price')
plt.title('Linear Regression Model')
plt.show()

# %% [markdown]
# 如果我们的预测值与实际值相同，则该图将是直线，y=x因为每个预测值x将等于每个实际值y。

# %% [markdown]
# ## 尝试改进模型

# %% [markdown]
# 再次实例化模型。`Ridge Regularization`模型采用一个参数`alpha`来控制正则化的强度。

# %%
for i in range (-2, 3):
    alpha = 10**i
    rm = linear_model.Ridge(alpha=alpha)
    ridge_model = rm.fit(X_train, y_train)
    preds_ridge = ridge_model.predict(X_test)

    plt.scatter(preds_ridge, actual_values, alpha=.75, color='b')
    plt.xlabel('Predicted Price')
    plt.ylabel('Actual Price')
    plt.title('Ridge Regularization with alpha = {}'.format(alpha))
    overlay = 'R^2 is: {}\nRMSE is: {}'.format(
                    ridge_model.score(X_test, y_test),
                    mean_squared_error(y_test, preds_ridge))
    plt.annotate(s=overlay,xy=(12.1,10.6),size='x-large')
    plt.show()

# %% [markdown]
# ## 提交
# 我们需要创建一个csv包含数据集中SalePrice每个观测值的预测值test.csv。

# %% [markdown]
# 第一列必须包含来自测试数据的ID

# %%
submission = pd.DataFrame()
submission['Id'] = test.Id
feats = test.select_dtypes(
        include=[np.number]).drop(['Id'], axis=1).interpolate()

# %% [markdown]
# 产生预测并把预测转换成正确的形式
# * 之前采用`np.log()`转换数据，现在要用`np.exp()`把数据转回来

# %%
predictions = model.predict(feats)
final_predictions = np.exp(predictions)

# %%
print ("Original predictions are: \n", predictions[:5], "\n")
print ("Final predictions are: \n", final_predictions[:5])
# Out:
# Original predictions are:
#  [ 11.76725362  11.71929504  12.07656074  12.20632678  12.11217655]
#
# Final predictions are:
#  [ 128959.49172586  122920.74024361  175704.82598102  200050.83263755
#   182075.46986404]

# %% [markdown]
# 查看预测结果

# %%
submission['SalePrice'] = final_predictions
submission.head()
# Out:
#      Id      SalePrice
# 0  1461  128959.491726
# 1  1462  122920.740244
# 2  1463  175704.825981
# 3  1464  200050.832638
# 4  1465  182075.469864

# %% [markdown]
# 保存预测结果到`csv`文件

# %%
submission.to_csv('submission1.csv', index=False)
